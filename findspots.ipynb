# %%
import numpy as np
from scipy.ndimage import gaussian_filter
from skimage.feature import peak_local_max
import tifffile as tiff
import os
import matplotlib.pyplot as plt

# Function to create a sphere
def create_sphere(center, radius, shape):
    z, y, x = np.indices(shape)
    distance = np.sqrt((z - center[0])**2 + (y - center[1])**2 + (x - center[2])**2)
    return distance <= radius

# Function to create a mask for a single 3D image
def generate_mask(image_3d, sigma=(1, 1, 1), threshold_percentile=99, spot_radius=2):
    # Apply Gaussian filter
    smoothed_image = gaussian_filter(image_3d, sigma=sigma)

    # Thresholding to find bright spots
    threshold = np.percentile(smoothed_image, threshold_percentile)
    binary_image = smoothed_image > threshold

    # Find local maxima for spot centers
    coordinates = peak_local_max(smoothed_image, min_distance=2, threshold_abs=threshold)

    # Create an empty mask
    mask = np.zeros_like(image_3d, dtype=np.uint8)

    # Add spheres to the mask at detected spot locations
    for coord in coordinates:
        z, y, x = coord
        sphere_mask = create_sphere((z, y, x), spot_radius, image_3d.shape)
        mask[sphere_mask] = 1

    return mask

# Load the 5D image (tzcyx)
image_path = "2024-11-07_MC256_slide6_Capture_8_cropped.tif"  # Replace with your image file path
image = tiff.imread(image_path)  # Shape: (time, z, channel, y, x)

# Output file
output_file = "spotmask.tif"  # Replace with your desired output path

# Ensure the image is in tzcyx format and process channel 1 (index 0)
assert image.ndim == 5, "Input image must be a 5D stack (tzcyx)."
channel_index = 0  # Index for channel 1
time_points, z_slices, _, height, width = image.shape
processed_masks = np.zeros((time_points, z_slices, height, width), dtype=np.uint8)  # tz, y, x

# Process each time point
for t in range(time_points):
    print(f"Processing time point {t + 1}/{time_points}...")
    image_3d = image[t, :, channel_index, :, :]  # Extract zyx stack for channel 1
    mask = generate_mask(image_3d, sigma=(1, 1, 1), threshold_percentile=99, spot_radius=2)
    processed_masks[t] = mask  # Save the mask

# Save the output mask as a 5D TIFF stack
tiff.imwrite(output_file, processed_masks, dtype=np.uint8)
print(f"Processing complete. Masks saved to: {output_file}")
# Out:
# Processing time point 1/127...

# %%
import cupy as cp
from cupyx.scipy.ndimage import gaussian_filter
from skimage.feature import peak_local_max
import tifffile as tiff
import numpy as np  # Still used for some CPU-based operations

# Function to create a sphere
def create_sphere(center, radius, shape):
    z, y, x = cp.indices(shape)
    distance = cp.sqrt((z - center[0])**2 + (y - center[1])**2 + (x - center[2])**2)
    return distance <= radius

# Function to create a mask for a single 3D image
def generate_mask(image_3d, sigma=(1, 1, 1), threshold_percentile=99.5, spot_radius=2):
    # Transfer image to GPU
    image_3d_gpu = cp.asarray(image_3d)

    # Apply Gaussian filter on GPU
    smoothed_image = gaussian_filter(image_3d_gpu, sigma=sigma)

    # Thresholding to find bright spots (ensure threshold is NumPy scalar)
    threshold = cp.percentile(smoothed_image, threshold_percentile).item()
    smoothed_image_np = cp.asnumpy(smoothed_image)

    # Find local maxima for spot centers
    coordinates = peak_local_max(
        smoothed_image_np, min_distance=2, threshold_abs=threshold
    )
    
    # Count the number of spots
    num_spots = len(coordinates)
    print(f"Number of spots detected: {num_spots}")

    # Create an empty mask on GPU
    mask = cp.zeros_like(image_3d_gpu, dtype=cp.uint8)

    # Add spheres to the mask at detected spot locations
    for coord in coordinates:
        z, y, x = coord
        sphere_mask = create_sphere((z, y, x), spot_radius, image_3d_gpu.shape)
        mask[sphere_mask] = 1

    # Transfer mask back to CPU
    return cp.asnumpy(mask), num_spots

# Load the 5D image (tzcyx)
image_path = "2024-11-07_MC256_slide6_Capture_8_cropped.tif"  # Replace with your image file path
image = tiff.imread(image_path)  # Shape: (time, z, channel, y, x)

threshold = 99.7
sigma = 2
spot_radius = 3
# Output file
output_file = f"spotmask_every_10th_threshold{threshold}_sigma_{sigma}_spotradius{spot_radius}.tif"  # Replace with your desired output path

# Ensure the image is in tzcyx format and process channel 1 (index 0)
assert image.ndim == 5, "Input image must be a 5D stack (tzcyx)."
channel_index = 0  # Index for channel 1
time_points, z_slices, _, height, width = image.shape
processed_masks = np.zeros((time_points, z_slices, height, width), dtype=np.uint8)  # tz, y, x

# Process every 10th time point
total_spots = 0
for t in range(0, time_points, 1):
    print(f"Processing time point {t + 1}/{time_points}...")
    image_3d = image[t, :, channel_index, :, :]  # Extract zyx stack for channel 1
    mask, num_spots = generate_mask(image_3d, sigma=(sigma, sigma, sigma), threshold_percentile=threshold, spot_radius=spot_radius)
    processed_masks[t] = mask  # Save the mask for the processed time point
    total_spots += num_spots
    print(f"Frame {t}: Detected {num_spots} spots")

# Print the total number of spots across all frames
print(f"Total spots detected across all processed frames: {total_spots}")

# Save the output mask as a 5D TIFF stack
# Function to save the hyperstack TIFF
def save_hyperstack_tiff(segmented_movie, output_path):
    tiff.imwrite(
        output_path,
        segmented_movie,
        imagej=True,
        metadata={'axes': 'TZYX'},
        resolution=(1/0.1625, 1/0.1625),
    )
    print(f"Saved segmented movie as ImageJ hyperstack to {output_path}")


save_hyperstack_tiff(processed_masks, output_file)
print(f"Processing complete. Masks for every 10th frame saved to: {output_file}")
# Out:
# Processing time point 1/127...
# Number of spots detected: 291
# Frame 0: Detected 291 spots
# Processing time point 2/127...
# Number of spots detected: 228
# Frame 1: Detected 228 spots
# Processing time point 3/127...
# Number of spots detected: 233
# Frame 2: Detected 233 spots
# Processing time point 4/127...
# Number of spots detected: 228
# Frame 3: Detected 228 spots
# Processing time point 5/127...
# Number of spots detected: 234
# Frame 4: Detected 234 spots
# Processing time point 6/127...
# Number of spots detected: 248
# Frame 5: Detected 248 spots
# Processing time point 7/127...
# Number of spots detected: 232
# Frame 6: Detected 232 spots
# Processing time point 8/127...
# Number of spots detected: 249
# Frame 7: Detected 249 spots
# Processing time point 9/127...
# Number of spots detected: 265
# Frame 8: Detected 265 spots
# Processing time point 10/127...
# Number of spots detected: 250
# Frame 9: Detected 250 spots
# Processing time point 11/127...
# Number of spots detected: 235
# Frame 10: Detected 235 spots
# Processing time point 12/127...
# Number of spots detected: 284
# Frame 11: Detected 284 spots
# Processing time point 13/127...
# Number of spots detected: 274
# Frame 12: Detected 274 spots
# Processing time point 14/127...
# Number of spots detected: 252
# Frame 13: Detected 252 spots
# Processing time point 15/127...
# Number of spots detected: 274
# Frame 14: Detected 274 spots
# Processing time point 16/127...
# Number of spots detected: 252
# Frame 15: Detected 252 spots
# Processing time point 17/127...
# Number of spots detected: 263
# Frame 16: Detected 263 spots
# Processing time point 18/127...
# Number of spots detected: 255
# Frame 17: Detected 255 spots
# Processing time point 19/127...
# Number of spots detected: 251
# Frame 18: Detected 251 spots
# Processing time point 20/127...
# Number of spots detected: 197
# Frame 19: Detected 197 spots
# Processing time point 21/127...
# Number of spots detected: 238
# Frame 20: Detected 238 spots
# Processing time point 22/127...
# Number of spots detected: 247
# Frame 21: Detected 247 spots
# Processing time point 23/127...
# Number of spots detected: 225
# Frame 22: Detected 225 spots
# Processing time point 24/127...
# Number of spots detected: 289
# Frame 23: Detected 289 spots
# Processing time point 25/127...
# Number of spots detected: 296
# Frame 24: Detected 296 spots
# Processing time point 26/127...
# Number of spots detected: 230
# Frame 25: Detected 230 spots
# Processing time point 27/127...
# Number of spots detected: 242
# Frame 26: Detected 242 spots
# Processing time point 28/127...
# Number of spots detected: 268
# Frame 27: Detected 268 spots
# Processing time point 29/127...
# Number of spots detected: 257
# Frame 28: Detected 257 spots
# Processing time point 30/127...
# Number of spots detected: 271
# Frame 29: Detected 271 spots
# Processing time point 31/127...
# Number of spots detected: 222
# Frame 30: Detected 222 spots
# Processing time point 32/127...
# Number of spots detected: 208
# Frame 31: Detected 208 spots
# Processing time point 33/127...
# Number of spots detected: 213
# Frame 32: Detected 213 spots
# Processing time point 34/127...
# Number of spots detected: 242
# Frame 33: Detected 242 spots
# Processing time point 35/127...
# Number of spots detected: 209
# Frame 34: Detected 209 spots
# Processing time point 36/127...
# Number of spots detected: 188
# Frame 35: Detected 188 spots
# Processing time point 37/127...
# Number of spots detected: 195
# Frame 36: Detected 195 spots
# Processing time point 38/127...
# Number of spots detected: 181
# Frame 37: Detected 181 spots
# Processing time point 39/127...
# Number of spots detected: 186
# Frame 38: Detected 186 spots
# Processing time point 40/127...
# Number of spots detected: 207
# Frame 39: Detected 207 spots
# Processing time point 41/127...
# Number of spots detected: 174
# Frame 40: Detected 174 spots
# Processing time point 42/127...
# Number of spots detected: 139
# Frame 41: Detected 139 spots
# Processing time point 43/127...
# Number of spots detected: 132
# Frame 42: Detected 132 spots
# Processing time point 44/127...
# Number of spots detected: 99
# Frame 43: Detected 99 spots
# Processing time point 45/127...
# Number of spots detected: 113
# Frame 44: Detected 113 spots
# Processing time point 46/127...
# Number of spots detected: 112
# Frame 45: Detected 112 spots
# Processing time point 47/127...
# Number of spots detected: 104
# Frame 46: Detected 104 spots
# Processing time point 48/127...
# Number of spots detected: 108
# Frame 47: Detected 108 spots
# Processing time point 49/127...
# Number of spots detected: 100
# Frame 48: Detected 100 spots
# Processing time point 50/127...
# Number of spots detected: 89
# Frame 49: Detected 89 spots
# Processing time point 51/127...
# Number of spots detected: 73
# Frame 50: Detected 73 spots
# Processing time point 52/127...
# Number of spots detected: 84
# Frame 51: Detected 84 spots
# Processing time point 53/127...
# Number of spots detected: 77
# Frame 52: Detected 77 spots
# Processing time point 54/127...
# Number of spots detected: 80
# Frame 53: Detected 80 spots
# Processing time point 55/127...
# Number of spots detected: 70
# Frame 54: Detected 70 spots
# Processing time point 56/127...
# Number of spots detected: 71
# Frame 55: Detected 71 spots
# Processing time point 57/127...
# Number of spots detected: 69
# Frame 56: Detected 69 spots
# Processing time point 58/127...
# Number of spots detected: 66
# Frame 57: Detected 66 spots
# Processing time point 59/127...
# Number of spots detected: 70
# Frame 58: Detected 70 spots
# Processing time point 60/127...
# Number of spots detected: 69
# Frame 59: Detected 69 spots
# Processing time point 61/127...
# Number of spots detected: 68
# Frame 60: Detected 68 spots
# Processing time point 62/127...
# Number of spots detected: 67
# Frame 61: Detected 67 spots
# Processing time point 63/127...
# Number of spots detected: 67
# Frame 62: Detected 67 spots
# Processing time point 64/127...
# Number of spots detected: 69
# Frame 63: Detected 69 spots
# Processing time point 65/127...
# Number of spots detected: 67
# Frame 64: Detected 67 spots
# Processing time point 66/127...
# Number of spots detected: 65
# Frame 65: Detected 65 spots
# Processing time point 67/127...
# Number of spots detected: 65
# Frame 66: Detected 65 spots
# Processing time point 68/127...
# Number of spots detected: 65
# Frame 67: Detected 65 spots
# Processing time point 69/127...
# Number of spots detected: 68
# Frame 68: Detected 68 spots
# Processing time point 70/127...
# Number of spots detected: 71
# Frame 69: Detected 71 spots
# Processing time point 71/127...
# Number of spots detected: 71
# Frame 70: Detected 71 spots
# Processing time point 72/127...
# Number of spots detected: 73
# Frame 71: Detected 73 spots
# Processing time point 73/127...
# Number of spots detected: 74
# Frame 72: Detected 74 spots
# Processing time point 74/127...
# Number of spots detected: 72
# Frame 73: Detected 72 spots
# Processing time point 75/127...
# Number of spots detected: 74
# Frame 74: Detected 74 spots
# Processing time point 76/127...
# Number of spots detected: 74
# Frame 75: Detected 74 spots
# Processing time point 77/127...
# Number of spots detected: 76
# Frame 76: Detected 76 spots
# Processing time point 78/127...
# Number of spots detected: 75
# Frame 77: Detected 75 spots
# Processing time point 79/127...
# Number of spots detected: 78
# Frame 78: Detected 78 spots
# Processing time point 80/127...
# Number of spots detected: 78
# Frame 79: Detected 78 spots
# Processing time point 81/127...
# Number of spots detected: 73
# Frame 80: Detected 73 spots
# Processing time point 82/127...
# Number of spots detected: 70
# Frame 81: Detected 70 spots
# Processing time point 83/127...
# Number of spots detected: 68
# Frame 82: Detected 68 spots
# Processing time point 84/127...
# Number of spots detected: 73
# Frame 83: Detected 73 spots
# Processing time point 85/127...
# Number of spots detected: 72
# Frame 84: Detected 72 spots
# Processing time point 86/127...
# Number of spots detected: 73
# Frame 85: Detected 73 spots
# Processing time point 87/127...
# Number of spots detected: 71
# Frame 86: Detected 71 spots
# Processing time point 88/127...
# Number of spots detected: 71
# Frame 87: Detected 71 spots
# Processing time point 89/127...
# Number of spots detected: 73
# Frame 88: Detected 73 spots
# Processing time point 90/127...
# Number of spots detected: 75
# Frame 89: Detected 75 spots
# Processing time point 91/127...
# Number of spots detected: 74
# Frame 90: Detected 74 spots
# Processing time point 92/127...
# Number of spots detected: 74
# Frame 91: Detected 74 spots
# Processing time point 93/127...
# Number of spots detected: 76
# Frame 92: Detected 76 spots
# Processing time point 94/127...
# Number of spots detected: 79
# Frame 93: Detected 79 spots
# Processing time point 95/127...
# Number of spots detected: 75
# Frame 94: Detected 75 spots
# Processing time point 96/127...
# Number of spots detected: 77
# Frame 95: Detected 77 spots
# Processing time point 97/127...
# Number of spots detected: 75
# Frame 96: Detected 75 spots
# Processing time point 98/127...
# Number of spots detected: 75
# Frame 97: Detected 75 spots
# Processing time point 99/127...
# Number of spots detected: 79
# Frame 98: Detected 79 spots
# Processing time point 100/127...
# Number of spots detected: 76
# Frame 99: Detected 76 spots
# Processing time point 101/127...
# Number of spots detected: 75
# Frame 100: Detected 75 spots
# Processing time point 102/127...
# Number of spots detected: 76
# Frame 101: Detected 76 spots
# Processing time point 103/127...
# Number of spots detected: 75
# Frame 102: Detected 75 spots
# Processing time point 104/127...
# Number of spots detected: 75
# Frame 103: Detected 75 spots
# Processing time point 105/127...
# Number of spots detected: 76
# Frame 104: Detected 76 spots
# Processing time point 106/127...
# Number of spots detected: 80
# Frame 105: Detected 80 spots
# Processing time point 107/127...
# Number of spots detected: 78
# Frame 106: Detected 78 spots
# Processing time point 108/127...
# Number of spots detected: 81
# Frame 107: Detected 81 spots
# Processing time point 109/127...
# Number of spots detected: 80
# Frame 108: Detected 80 spots
# Processing time point 110/127...
# Number of spots detected: 82
# Frame 109: Detected 82 spots
# Processing time point 111/127...
# Number of spots detected: 82
# Frame 110: Detected 82 spots
# Processing time point 112/127...
# Number of spots detected: 79
# Frame 111: Detected 79 spots
# Processing time point 113/127...
# Number of spots detected: 78
# Frame 112: Detected 78 spots
# Processing time point 114/127...
# Number of spots detected: 80
# Frame 113: Detected 80 spots
# Processing time point 115/127...
# Number of spots detected: 81
# Frame 114: Detected 81 spots
# Processing time point 116/127...
# Number of spots detected: 80
# Frame 115: Detected 80 spots
# Processing time point 117/127...
# Number of spots detected: 78
# Frame 116: Detected 78 spots
# Processing time point 118/127...
# Number of spots detected: 79
# Frame 117: Detected 79 spots
# Processing time point 119/127...
# Number of spots detected: 80
# Frame 118: Detected 80 spots
# Processing time point 120/127...
# Number of spots detected: 80
# Frame 119: Detected 80 spots
# Processing time point 121/127...
# Number of spots detected: 79
# Frame 120: Detected 79 spots
# Processing time point 122/127...
# Number of spots detected: 81
# Frame 121: Detected 81 spots
# Processing time point 123/127...
# Number of spots detected: 82
# Frame 122: Detected 82 spots
# Processing time point 124/127...
# Number of spots detected: 80
# Frame 123: Detected 80 spots
# Processing time point 125/127...
# Number of spots detected: 82
# Frame 124: Detected 82 spots
# Processing time point 126/127...
# Number of spots detected: 83
# Frame 125: Detected 83 spots
# Processing time point 127/127...
# Number of spots detected: 66
# Frame 126: Detected 66 spots
# Total spots detected across all processed frames: 16532
# Saved segmented movie as ImageJ hyperstack to spotmask_every_10th_threshold99.7_sigma_2_spotradius3.tif
# Processing complete. Masks for every 10th frame saved to: spotmask_every_10th_threshold99.7_sigma_2_spotradius3.tif

# %%
import cupy as cp
from cupyx.scipy.ndimage import gaussian_filter
from skimage.feature import peak_local_max
import tifffile as tiff
import numpy as np

# Function to create a sphere
def create_sphere(center, radius, shape):
    z, y, x = cp.indices(shape)
    distance = cp.sqrt((z - center[0])**2 + (y - center[1])**2 + (x - center[2])**2)
    return distance <= radius

# Function to create a mask for a batch of 3D images
def generate_mask_batch(images_3d, sigma=(1, 1, 1), threshold_percentile=99, spot_radius=2):
    # Transfer images to GPU
    images_gpu = cp.asarray(images_3d)

    # Apply Gaussian filter to all images in the batch
    smoothed_images = cp.array([gaussian_filter(img, sigma=sigma) for img in images_gpu])

    # Process each image individually
    masks = []
    for smoothed_image in smoothed_images:
        # Thresholding to find bright spots
        threshold = cp.percentile(smoothed_image, threshold_percentile).item()
        smoothed_image_np = cp.asnumpy(smoothed_image)

        # Find local maxima
        coordinates = peak_local_max(
            smoothed_image_np, min_distance=2, threshold_abs=threshold
        )

        # Create an empty mask
        mask = cp.zeros_like(smoothed_image, dtype=cp.uint8)

        # Add spheres to the mask at detected spot locations
        for coord in coordinates:
            z, y, x = coord
            sphere_mask = create_sphere((z, y, x), spot_radius, smoothed_image.shape)
            mask[sphere_mask] = 1

        # Save the mask
        masks.append(cp.asnumpy(mask))

    return masks

# Function to save the hyperstack TIFF
def save_hyperstack_tiff(segmented_movie, output_path):
    tiff.imwrite(
        output_path,
        segmented_movie,
        imagej=True,
        metadata={'axes': 'TZYX'},
        resolution=(1/0.1625, 1/0.1625),
    )
    print(f"Saved segmented movie as ImageJ hyperstack to {output_path}")

# Load the 5D image (tzcyx)
image_path = "2024-11-07_MC256_slide6_Capture_8_cropped.tif"
image = tiff.imread(image_path)  # Shape: (time, z, channel, y, x)

# Output file
output_file = "spotmask_hyperstack.tif"

# Ensure the image is in tzcyx format and process channel 1 (index 0)
assert image.ndim == 5, "Input image must be a 5D stack (tzcyx)."
channel_index = 0  # Index for channel 1
time_points, z_slices, _, height, width = image.shape
processed_masks = np.zeros((time_points, z_slices, height, width), dtype=np.uint8)

# Set batch size
batch_size = 4  # Number of time points to process in parallel

# Process in batches
for batch_start in range(0, time_points, batch_size):
    batch_end = min(batch_start + batch_size, time_points)
    print(f"Processing time points {batch_start + 1} to {batch_end}...")
    
    # Extract batch
    batch_images = image[batch_start:batch_end, :, channel_index, :, :]  # Shape: (batch, z, y, x)
    
    # Generate masks for the batch
    batch_masks = generate_mask_batch(batch_images, sigma=(1, 1, 1), threshold_percentile=99, spot_radius=2)

    # Save the masks back into the full array
    for i, mask in enumerate(batch_masks):
        processed_masks[batch_start + i] = mask

# Save the output mask as a 5D TIFF hyperstack
save_hyperstack_tiff(processed_masks, output_file)
# Out:
# Processing time points 1 to 4...
# Processing time points 5 to 8...
